# %%
import pandas as pd

# %%
data = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/E0.csv")
data
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E0  05/08/2022  20:00  Crystal Palace        Arsenal     0     2   A
# 1    E0  06/08/2022  12:30          Fulham      Liverpool     2     2   D
# 2    E0  06/08/2022  15:00     Bournemouth    Aston Villa     2     0   H
# 3    E0  06/08/2022  15:00           Leeds         Wolves     2     1   H
# 4    E0  06/08/2022  15:00       Newcastle  Nott'm Forest     2     0   H
# ..   ..         ...    ...             ...            ...   ...   ...  ..
# 214  E0  11/02/2023  15:00       Leicester      Tottenham     4     1   H
# 215  E0  11/02/2023  15:00     Southampton         Wolves     1     2   A
# 216  E0  11/02/2023  17:30     Bournemouth      Newcastle     1     1   D
# 217  E0  12/02/2023  14:00           Leeds     Man United     0     2   A
# 218  E0  12/02/2023  16:30        Man City    Aston Villa     3     1   H
#
#      HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# ...

# %%
data.columns
# Out:
# Index(['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
#        'HTHG', 'HTAG',
#        ...
#        'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH',
#        'MaxCAHA', 'AvgCAHH', 'AvgCAHA'],
#       dtype='object', length=106)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Columns: 106 entries, Div to AvgCAHA
# dtypes: float64(82), int64(16), object(8)
# memory usage: 181.5+ KB

# %%
data.rename(columns={'FTHG': 'Home Goals', 'FTAG': 'Away Goasl'}, inplace=True)
data
# Out:
#     Div        Date   Time        HomeTeam       AwayTeam  Home Goals  \
# 0    E0  05/08/2022  20:00  Crystal Palace        Arsenal           0
# 1    E0  06/08/2022  12:30          Fulham      Liverpool           2
# 2    E0  06/08/2022  15:00     Bournemouth    Aston Villa           2
# 3    E0  06/08/2022  15:00           Leeds         Wolves           2
# 4    E0  06/08/2022  15:00       Newcastle  Nott'm Forest           2
# ..   ..         ...    ...             ...            ...         ...
# 214  E0  11/02/2023  15:00       Leicester      Tottenham           4
# 215  E0  11/02/2023  15:00     Southampton         Wolves           1
# 216  E0  11/02/2023  17:30     Bournemouth      Newcastle           1
# 217  E0  12/02/2023  14:00           Leeds     Man United           0
# 218  E0  12/02/2023  16:30        Man City    Aston Villa           3
#
#      Away Goasl FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  \
# ...
